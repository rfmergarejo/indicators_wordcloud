# %% [markdown]
# # Reguetton quality check

# %%
import pandas as pd
import numpy as np

from wordcloud import WordCloud, STOPWORDS
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
with open("DY - Despacito.txt", mode = "r", encoding = 'utf-8') as f:
    ff = f.read()
    lyrics = f.read().strip().split()

#despacito = pd.DataFrame(data={'words' : lyrics})

#stopwords = set(STOPWORDS)
#stopwords.add("Luis", "Fonsi")
#wordcloud = WordCloud(stopwords = stopwords, background_color="white", max_words=len(ff), repeat=False)
wordcloud = WordCloud(background_color="white", max_words=len(ff), repeat=False)

wc = wordcloud.generate(ff)


plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()
